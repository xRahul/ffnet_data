# %%
import requests
from bs4 import BeautifulSoup
import locale
import json
import csv

# %%
def merge_two_dicts(x, y):
    """Given two dicts, merge them into a new dict as a shallow copy."""
    z = x.copy()
    z.update(y)
    return z

# %%
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' )
# Out:
# 'en_US.UTF-8'

# %%
page = requests.get("https://www.fanfiction.net/u/2583361/")
print("Getting User Page - Completed")
# Out:
# Getting User Page
# Getting User Page - Completed

# %%
soup = BeautifulSoup(page.content, 'html.parser')
fav_stories_div = soup.find_all('div', class_='z-list favstories')
stories_metadata = []

# %%
for n, story in enumerate(fav_stories_div):
	story_elements = list(story.children)
	desc_with_metadata = str(story.find_all('div', class_='z-indent z-padtop')[0])
	desc_metadata = str(story.find_all('div', class_='z-indent z-padtop')[0].find_all('div', class_="z-padtop2 xgray")[0])
	desc_metadata_soup = story.find_all('div', class_='z-indent z-padtop')[0].find_all('div', class_="z-padtop2 xgray")[0]
	desc_without_metadata = desc_with_metadata.replace(desc_metadata, "")
	desc_without_metadata_soup = BeautifulSoup(desc_without_metadata, 'html.parser')
	desc_metadata_list = [x.strip() for x in desc_metadata_soup.get_text().split(' - ')]

	story_metadata = {
		"story_name": story_elements[0].get_text(),
		"story_start_url_relative": story_elements[0].get('href'),
		"story_end_url_relative": story_elements[2].get('href'),
		"author_name": story_elements[4].get_text(),
		"author_url_relative": story_elements[4].get('href'),
		"reviews_url_relative": story.find_all('a', class_='reviews')[0].get('href'),
		"story_summary": desc_without_metadata_soup.get_text()
	}

	if "Crossover" in desc_metadata_list[0]:
		del desc_metadata_list[0]
		story_metadata = merge_two_dicts(story_metadata, {
			"story_crossover": "Y",
			"story_parent": desc_metadata_list[0].split(' & ')
		})
	else:
		story_metadata = merge_two_dicts(story_metadata, {
			"story_crossover": "N",
			"story_parent": [desc_metadata_list[0]]
		})
	if "Chapters" in desc_metadata_list[3]:
		desc_metadata_list.insert(3, "Unknown")
	if "Published" in desc_metadata_list[9]:
		desc_metadata_list.insert(9, "Updated: Unknown")
	if "Complete" == desc_metadata_list[-1]:
		del desc_metadata_list[-1]
		story_metadata = merge_two_dicts(story_metadata, {
			"story_complete": "Y"
		})
	else:
		story_metadata = merge_two_dicts(story_metadata, {
			"story_complete": "N"
		})
	if "Published" in desc_metadata_list[-1]:
		desc_metadata_list.append("Unknown")

	if len(desc_metadata_list) == 12:
		try:
			desc_metadata_dict = {
				"story_parent": desc_metadata_list[0],
				"story_rating": desc_metadata_list[1].split(': ')[1],
				"story_language": desc_metadata_list[2],
				"story_genre": desc_metadata_list[3],
				"story_chapter_count": desc_metadata_list[4].split(': ')[1],
				"story_word_count": locale.atoi(desc_metadata_list[5].split(': ')[1]),
				"story_review_count": desc_metadata_list[6].split(': ')[1],
				"story_favourite_count": locale.atoi(desc_metadata_list[7].split(': ')[1]),
				"story_follow_count": locale.atoi(desc_metadata_list[8].split(': ')[1]),
				"story_last_updated_date": desc_metadata_list[9].split(': ')[1],
				"story_published_date": desc_metadata_list[10].split(': ')[1],
				"story_main_characters": desc_metadata_list[11].split(', ')
			}
		except IndexError as e:
			print e, len(desc_metadata_list), story_metadata, desc_metadata_list
			break
		story_metadata = merge_two_dicts(story_metadata, desc_metadata_dict)
	else:
		print len(desc_metadata_list), story_metadata, desc_metadata_list
	stories_metadata.append(story_metadata)

# %%
with open('fav_stories_metadata.json', 'w') as outfile_json:
    json.dump(stories_metadata, outfile_json)

# %%
print(stories_metadata)
# Out:
# [{'story_last_updated_date': u'1/31', 'story_crossover': 'N', 'story_complete': 'N', 'story_favourite_count': 4843, 'story_word_count': 720488, 'author_name': u"I'mjusttryingtofindmyway", 'story_summary': u'Percy is given the gift of the Gamer turning his life into a video game with levels, dungeons and skill points. Now Percy, armed with this amazing ability, sets out to prove himself to the world of the gods and humans by becoming the best at he can be and fulfilling his destiny. And eventually maybe even find love. Swearing, OP Percy, oh and REVIEWS!', 'story_end_url_relative': u'/s/11697391/60/Percy-Jackson-and-the-Game', 'story_parent': u'Percy Jackson and the Olympians', 'story_rating': u'M', 'author_url_relative': u'/u/5380086/I-mjusttryingtofindmyway', 'story_language': u'English', 'reviews_url_relative': u'/r/11697391/', 'story_start_url_relative': u'/s/11697391/1/Percy-Jackson-and-the-Game', 'story_main_characters': [u'Percy J.', u'Thalia G.', u'Artemis'], 'story_follow_count': 5101, 'story_genre': u'Fantasy/Adventure', 'story_name': u'Percy Jackson and the Game', 'story_chapter_count': u'60', 'story_published_date': u'12/28/2015', 'story_review_count': u'7043'}, {'story_last_updated_date': u'1/28', 'story_crossover': 'N', 'story_complete': 'N', 'story_favourite_count': 1132, 'story_word_count': 122773, 'author_name': u'Kenchi618', 'story_summary': u'The life of a young mutant is perilous enough on its own. Follow the experiences of a student entering the hallowed halls of the Xavier Institute for Higher Learning, learning just what it takes and what it means to count himself as one of a race that is feared and targeted by many. Welcome to the X-Men, Bellamy Marcher - Hope you survive the experience.', 'story_end_url_relative': u'/s/11874143/11/Extraordinary-Times', 'story_parent': u'X-Men', 'story_rating': u'M', 'author_url_relative': u'/u/2218705/Kenchi618', 'story_language': u'English', 'reviews_url_relative': u'/r/11874143/', 'story_start_url_relative': u'/s/11874143/1/Extraordinary-Times', 'story_main_characters': [u'OC'], 'story_follow_count': 1111, 'story_genre': 'Unknown', 'story_name': u'Extraordinary Times', 'story_chapter_count': u'11', 'story_published_date': u'4/1/2016', 'story_review_count': u'651'}, {'story_last_updated_date': u'1/22', 'story_crossover': 'N', 'story_complete': 'N', 'story_favourite_count': 3944, 'story_word_count': 110493, 'author_name': u'Odin999', 'story_summary': u"Harry Potter meets some very interesting people in his youth, they help him grow to be someone the Wizarding World never expected. Dumbledore will realize sometimes the best plans don't go how you want them to.", 'story_end_url_relative': u'/s/10507423/23/Wizard-Kingpin', 'story_parent': u'Harry Potter', 'story_rating': u'M', 'author_url_relative': u'/u/3928554/Odin999', 'story_language': u'English', 'reviews_url_relative': u'/r/10507423/', 'story_start_url_relative': u'/s/10507423/1/Wizard-Kingpin', 'story_main_characters': [u'Harry P.'], 'story_follow_count': 4941, 'story_genre': u'Adventure/Crime', 'story_name': u'Wizard Kingpin', 'story_chapter_count': u'23', 'story_published_date': u'7/4/2014', 'story_review_count': u'1182'}, {'story_last_updated_date': u'1/16', 'story_crossover': 'N', 'story_complete': 'N', 'story_favourite_count': 5081, 'story_word_count': 317389, 'author_name': u'Concept101', 'story_summary': u"YEAR 1 AND 2 COMPLETE! With his life turned into a Game, Harry now has to raise a Phoenix, uncover the Founders' darkest secrets, deal with political manipulations and live through Hogwarts all while trying desperately to not swear too much. Powerful!Grey!Ravenclaw!Harry, GreaterGood!Dumbledore", 'story_end_url_relative': u'/s/11950816/42/Harry-Potter-and-the-Game', 'story_parent': u'Harry Potter', 'story_rating': u'T', 'author_url_relative': u'/u/7268383/Concept101', 'story_language': u'English', 'reviews_url_relative': u'/r/11950816/', 'story_start_url_relative': u'/s/11950816/1/Harry-Potter-and-the-Game' ...
